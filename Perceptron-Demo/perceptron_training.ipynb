# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('D:\Projects\Perceptron-Demo\dataset\placement.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\shusa\AppData\Local\Temp\ipykernel_2732\4254820039.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('D:\Projects\Perceptron-Demo\dataset\placement.csv')

# %%
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y, )
# Out:
# Perceptron()

# %%
param_grid = {
    'penalty': [None, 'l2', 'l1'],
    'alpha': [0.0001, 0.001, 0.01],
    'max_iter': [500, 1000, 2000],
    'tol': [1e-3, 1e-4],
    'eta0': [0.1, 0.01, 1],
    'shuffle': [True, False]
}

# %%
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(
    estimator=p,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=Perceptron(), n_jobs=-1,
#              param_grid={'alpha': [0.0001, 0.001, 0.01], 'eta0': [0.1, 0.01, 1],
#                          'max_iter': [500, 1000, 2000],
#                          'penalty': [None, 'l2', 'l1'],
#                          'shuffle': [True, False], 'tol': [0.001, 0.0001]},
#              scoring='accuracy')

# %%
print("Best parameters found: ", grid.best_params_)
# Out:
# Best parameters found:  {'alpha': 0.0001, 'eta0': 0.1, 'max_iter': 500, 'penalty': None, 'shuffle': True, 'tol': 0.001}

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

best_model = grid.best_estimator_

plot_decision_regions(
    X.values,
    y.values,
    clf=best_model,
    legend=2
)
# Out:
# d:\Projects\Perceptron-Demo\.perceptron\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.linear_model import Perceptron

model = Perceptron(
    penalty=grid.best_params_['penalty'],
    alpha=grid.best_params_['alpha'],
    max_iter=grid.best_params_['max_iter'],
    tol=grid.best_params_['tol'],
    eta0=grid.best_params_['eta0'],
    shuffle=grid.best_params_['shuffle']
)

model.fit(X, y)
# Out:
# Perceptron(eta0=0.1, max_iter=500)

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=model, legend=2)
# Out:
# d:\Projects\Perceptron-Demo\.perceptron\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
